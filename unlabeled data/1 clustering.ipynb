# %% [markdown]
# # unsupervised  learning: unlabeled  data

# %%
#uncovering  hidden patterns from unlabeled  data

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.cluster import KMeans

# %%
● clustering: grouping customers into distinct categories
● dimension reduction: compressing data using purchase patterns

# %%
arrays, features & samples
● NumPy array
● rows are samples with N dimensions
● columns are measurements (features)
● dimension = number of features (number of columns)
● unsupervised learning gives insights to problems with more than 2 dimensions (hard to visualize!)

# %% [markdown]
# ## k-means clustering with scikit-learn

# %%
● Finds clusters of samples
● Number of clusters must be specified

# %%
df1 = pd.read_csv("..\data\points1.csv")
points = np.array(df1)

# %%
df2 = pd.read_csv("..\data\points2.csv")

# %%
df2.dropna
df2.dtypes
# Out:
# 0.400233332000     float64
# -1.265444710000    float64
# dtype: object

# %%
newpoints = np.array(df2)
newpoints.dtype
# Out:
# dtype('float64')

# %%
# Create a KMeans instance with 3 clusters:
model = KMeans(n_clusters=3)
# Fit model to points
model.fit(points)
# Out:
# KMeans(algorithm='auto', copy_x=True, init='k-means++', max_iter=300,
#     n_clusters=3, n_init=10, n_jobs=1, precompute_distances='auto',
#     random_state=None, tol=0.0001, verbose=0)

# %%
# Determine the cluster labels of new_points
#labels = model.predict(newpoints)

# Use fit_predict to fit model and obtain cluster labels
labels = model.fit_predict(newpoints)
print(labels)
# Out:
# [1 2 0 1 0 1 1 1 2 0 1 1 2 2 1 2 2 1 1 2 1 0 1 0 2 1 2 2 0 0 1 1 1 2 0 1 1
#  0 1 2 0 0 2 0 1 2 2 1 1 1 1 2 2 0 0 2 2 2 0 0 1 1 1 0 1 2 1 0 2 0 0 0 1 0
#  2 2 0 1 2 0 2 0 1 2 1 2 0 1 1 1 0 1 1 0 2 2 2 2 0 1 0 2 2 0 0 1 0 2 2 0 2
#  2 2 1 1 1 1 2 2 1 0 1 2 1 0 2 1 2 2 1 2 1 2 0 1 0 0 1 2 0 1 0 0 2 1 1 0 2
#  0 2 1 0 2 2 0 2 1 1 2 1 2 2 1 1 0 1 1 2 0 2 0 0 1 0 1 1 0 0 2 0 0 0 2 1 1
#  0 2 0 2 2 1 1 1 0 1 1 1 2 2 0 1 0 0 0 2 1 1 1 1 1 1 2 2 1 2 2 2 2 1 2 2 1
#  1 0 2 0 0 2 0 2 0 2 1 1 2 1 1 1 2 0 0 2 1 1 2 1 2 2 1 2 2 0 2 0 0 0 1 2 2
#  2 0 1 0 2 0 2 2 1 0 0 0 2 1 1 1 0 1 2 2 1 0 0 2 0 0 2 0 1 0 2 2 2 2 1 2 2
#  1 1 0]

# %% [markdown]
# ### cluster labels for new samples

# %%
● New samples can be assigned to existing clusters
● k-means remembers the mean of each cluster (the "centroids")
● Finds the nearest centroid to each new sample

# %%
# Assign the columns of new_points: xs and ys
xs = newpoints[:,0]
ys = newpoints[:,1]
# Make a scatter plot of xs and ys, using labels to define the colors
plt.scatter(xs,ys,c=labels,alpha=0.5)
# Assign the cluster centers: centroids
centroids = model.cluster_centers_
# Assign the columns of centroids: centroids_x, centroids_y
centroids_x = centroids[:,0]
centroids_y = centroids[:,1]
# Make a scatter plot of centroids_x and centroids_y
plt.scatter(centroids_x,centroids_y,marker="D",s=50)
plt.show()
