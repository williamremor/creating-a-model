# %% [markdown]
# # TERA - Aula 27
# ## Clustering

# %% [markdown]
# Objetivos gerais de algoritmos de clustering:
# - Análise exploratória dos dados
# - Encontrar padrões e estruturas
# - Agrupar dados de forma a criar representações sumarizadas (sumarização de dados)

# %% [markdown]
# # Índice
#
# - [Exemplo inicial](#Exemplo-Inicial)
# - [K-Means](#K-Means)
#  - [Case K-Means Elo7](#Case-Cluster-Usuários-Elo7)
# - [DBSCAN](#DBSCAN)
# - [Case Elo7 - Cluster Frete](#Case-Elo7---Clustering-de-Frete)
# - [Hierarchical Clustering](#Hierarchical-Clustering)
#  - [Exercício Prático](#Exercício-prático-Hierarchical-Clustering)
# - [Comparação Métodos Clustering](#Comparação-métodos-clustering:)
# - [Case Elo7 - Motivos de Compra](#Case-Elo7---Motivos-de-Compra)

# %% [markdown]
# ### Exemplo Inicial
# Análise exploratória do comportamento dos usuários do Elo7.
#
# Dataset:
# - `tempo` (float): Tempo em segundos que um usuário permanece no site.
# - `ticket` (float): Valor gasto em reais no site.

# %%
# Imports usados no curso
# %matplotlib inline
import os
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
#from sklearn

sns.set(style="ticks")
plt.rcParams['figure.figsize'] = (12.0, 8.0)
plt.style.use('seaborn-colorblind')

# %%
# Pasta contendo os dados:
ROOT_FOLDER = os.path.realpath('..')
DATASET_FOLDER = os.path.join(ROOT_FOLDER,'datasets')

# %%
# Leitura dos dados
df_user_elo7 = pd.read_csv(os.path.join(DATASET_FOLDER, 'user_patterns_elo7_dataset.csv'), sep=';')

df_user_elo7.head(5)
# Out:
#         tempo     ticket
# 0  138.492732  63.029202
# 1  306.160891  75.160275
# 2  264.210040  74.064756
# 3  326.972183  95.059350
# 4  268.796360  47.015198

# %%
# Vamos plotar o gráfico
df_user_elo7.plot.scatter(x='tempo',y='ticket', alpha=0.5)
plt.xlabel('Tempo (s)')
plt.ylabel('Ticket (R$)')
plt.show()

# %% [markdown]
# #### Análise Exploratória
# - Média
# - Covariância
# - Tendência (Regressão Linear)

# %%
# Valor médio
user_elo7_mean = df_user_elo7.mean().values

# Covariância
user_elo7_cov = np.cov(df_user_elo7.values[:,0], df_user_elo7.values[:,1])

# Tendência
a, b = np.polyfit(df_user_elo7.values[:,0], df_user_elo7.values[:,1], deg=1)
f = lambda x: a*x + b

# %%
### Função auxiliar para plotar a elipse de confiança ###
from matplotlib.patches import Ellipse

def get_confidence_ellipse(x, y, nstd=2):
    def eigsorted(cov):
        vals, vecs = np.linalg.eigh(cov)
        order = vals.argsort()[::-1]
        return vals[order], vecs[:,order]

    cov = np.cov(x, y)
    vals, vecs = eigsorted(cov)
    theta = np.degrees(np.arctan2(*vecs[:,0][::-1]))
    w, h = 2 * nstd * np.sqrt(vals)
    ell = Ellipse(xy=(np.mean(x), np.mean(y)),
                  width=w, height=h,
                  angle=theta, color='red', 
                  fill=False)
    return ell

# %%
# Vamos plotar os dados no gráfico
df_user_elo7.plot.scatter(x='tempo',y='ticket', alpha=0.5)
plt.xlabel('Tempo (s)')
plt.ylabel('Ticket (R$)')

# Média
plt.plot(user_elo7_mean[0], user_elo7_mean[1], '*r', markersize=20)

# 2 desvios padrão
ell = get_confidence_ellipse(x=df_user_elo7.values[:,0],
                             y=df_user_elo7.values[:,1])
ax = plt.gca()
ax.add_patch(ell)

# Tendência
x = np.array([min(df_user_elo7.values[:,0]),max(df_user_elo7.values[:,0])])
plt.plot(x, f(x), '--g')

plt.show()

# %% [markdown]
# Há algo estranho nessa análise?
# - A análise está matematicamente correta, mas talvez não seja completa;
# - Precisamos levar em consideração possíveis grupos diferentes de usuários dentro dos dados. Quantos grupos você vê? Talvez entre 2 e 4 clusters?
#
# Vamos voltar para esse problema em breve.

# %% [markdown]
# ---
# ## K-Means
# ### Exemplo prático Clustering
#
# Vamos para um problema clássico.
# Utilizaremos o dataset Iris. O dataset contém os seguintes atributos:
#
# - `sepal_length`: Comprimento da sépala da flor
# - `sepal_width`: Largura da sépala
# - `petal_length`: Comprimento da pétala
# - `petal_width`: Largura da pétala
# - `species`: Espécie da flor
#
# ![iris](https://cdn-images-1.medium.com/max/1600/1*1q79O5DCx_XNrAARXSFzpg.png)

# %%
# Importe o dataset
df_iris = pd.read_csv(os.path.join(DATASET_FOLDER,'iris_dataset.csv'))

df_iris.head(5)
# Out:
#    sepal_length  sepal_width  petal_length  petal_width species
# 0           5.1          3.5           1.4          0.2  setosa
# 1           4.9          3.0           1.4          0.2  setosa
# 2           4.7          3.2           1.3          0.2  setosa
# 3           4.6          3.1           1.5          0.2  setosa
# 4           5.0          3.6           1.4          0.2  setosa

# %% [markdown]
# Como temos um vetor de features de 4 dimensões, não faz sentido tentarmos visualizar todas as dimensões em uma só figura. Entretanto, podemos visualizar a relação entre cada uma de suas features através de um mapa de dispersão pareado.

# %%
# Scatter plot pareado utilizando o Seaborn
sns.pairplot(df_iris, hue="species")
plt.show()

# %% [markdown]
# Podemos perceber que há uma boa separação de clusters utilizando as features `petal_length` e `petal_width`. Podemos utilizar apenas essas dimensões para a nossa análise.

# %%
# TODO
# Separe o dataset utilizando apenas as features `petal_length` e `petal_width` do dataframe
# Coloque essas colunas em um numpy array (dica: utilize o atributo df[...].values)
X = df_iris[['petal_length','petal_width']].values

# %%
# Plot dos dados
plt.scatter(x=X[:,0],y=X[:,1])
plt.xlabel('petal_length')
plt.ylabel('petal_width')
plt.show()

# %% [markdown]
# Nós já sabemos que existem três espécies no dataset, mas podemos tentar analisar se conseguiríamos encontrar esses clusters de maneira automática. Vamos utilizar o famoso algoritmo [**K-Means**](https://en.wikipedia.org/wiki/K-means_clustering) para achar esses clusters. Verifique no site do [scikit-learn](http://scikit-learn.org/stable/modules/generated/sklearn.cluster.KMeans.html) mais detalhes de implementação do algoritmo.

# %%
# TODO
# Importe o módulo do KMeans 
from sklearn.cluster import KMeans

# Crie uma instância do K-Means pelo sklearn
kmeans = KMeans(n_clusters=3)

# %%
# TODO
# Treine e aplique o modelo KMeans para o dataset X
results = kmeans.fit_predict(X)

# %%
# Crie uma coluna no dataframe df para incluir os resultados
df_iris['cluster'] = results

df_iris.head(5)
# Out:
#    sepal_length  sepal_width  petal_length  petal_width species  cluster
# 0           5.1          3.5           1.4          0.2  setosa        1
# 1           4.9          3.0           1.4          0.2  setosa        1
# 2           4.7          3.2           1.3          0.2  setosa        1
# 3           4.6          3.1           1.5          0.2  setosa        1
# 4           5.0          3.6           1.4          0.2  setosa        1

# %%
# Plote o mapa de dispersão (scatter plot) dos clusters gerados
# Veja o exemplo das moedas para se inspirar
sns.swarmplot(data=df_iris, x='petal_length', y='petal_width', hue='cluster')
plt.xlabel('petal_length')
plt.ylabel('petal_width')
plt.show()

# %% [markdown]
# Os clusters formados fazem sentido? Veja novamente o gráfico da separação das espécies para ver se os clusters têm relação com elas.

# %%
sns.swarmplot(data=df_iris, x='petal_length', y='petal_width', hue="species")
plt.xlabel('petal_length')
plt.ylabel('petal_width')
plt.show()

# %% [markdown]
# Podemos também utilizar a matriz de tabulação cruzada para verificar a relação dos clusters com as espécies.

# %%
# Apresente a matriz de cross-tabulation (Veja o exemplo das moedas)
ct = pd.crosstab(df_iris['cluster'], df_iris['species'])
print(ct)
# Out:
# species  setosa  versicolor  virginica
# cluster
# 0             0           2         46
# 1            50           0          0
# 2             0          48          4

# %% [markdown]
# Quais são as conclusões? O K-Means funcionou do jeito que era esperado?

# %% [markdown]
# #### Escolha do número de clusters
#
# Nós temos diversos métodos para escolher o número ideal de clusters. Alguns deles estão resumidos neste [artigo](https://en.wikipedia.org/wiki/Determining_the_number_of_clusters_in_a_data_set#The_Elbow_Method). O método mais utilizado, entretanto, é o método do "cotovelo" (*elbow method*).
#
# Mas, antes de falarmos do método do cotovelo, nós precisamos definir o que é um bom cluster. É claro que isso depende de cada caso, mas as seguintes características são desejadas para a maioria dos clusters:
# - Dados não muito dispersos -> Inércia
# - Dados dentro dos clusters possuem perfil semelhante
# - Quantidade aproximadamente uniforme de dados em cada cluster (controverso)
#
# #### Inércia
#
# A inércia de um cluster é definida como a soma das distâncias quadráticas de cada ponto de um cluster ao seu respectivo centroide, somada através de todos os clusters. Quanto maior é a inércia, maior será a dispersão dos clusters. Portanto, desejamos escolher um número de clusters que nos possibilite ter uma inércia baixa. Simples, mas temos um problema... O mínimo valor de inércia que podemos obter é quando cada ponto do nosso dataset pertence ao seu próprio cluster. Portanto, precisamos escolher um balanço entre baixa inércia e baixo número de clusters.
#
# Para isso, utilizamos o gráfico de cotovelo. O eixo horizontal do gráfico representa o número de clusters utilizados e o eixo vertical representa a inércia total dos clusters. O número de clusters ideal é definido como o ponto onde o gráfico se aproxima a uma horizontal (como o ponto de encontro do braço e antebraço).

# %% [markdown]
# Vamos apresentar o gráfico de inércia do problema anterior e verificar se escolhemos corretamente o número de clusters.

# %%
# Range de valores de clusters que vamos testar
k = range(1,8,1)

# Lista de inércias
inertias = []

# Para cada valor de k, ache a inércia
for i in k:
    # crie a instância
    kmeans = KMeans(n_clusters=i)

    # Treine o modelo
    model = kmeans.fit(X)

    # Ache a inercia dos clusters
    inertias.append(model.inertia_)
    
plt.plot(k, inertias, '-ob')
plt.xlabel('Clusters')
plt.ylabel('Inertia')
plt.grid()
plt.show()

# %% [markdown]
# Podemos verificar que o número de clusters ideal é 3. Essa análise nos mostra que escolhemos corretamente o número de clusters.

# %% [markdown]
# ---
# ## Case Cluster Usuários Elo7

# %% [markdown]
# Agora que já conhecemos o K-Means, vamos voltar para o problema dos usuários do Elo7. Será que conseguimos encontrar clusters?

# %%
# Veja novamente os dados
df_user_elo7.head()
# Out:
#         tempo     ticket
# 0  138.492732  63.029202
# 1  306.160891  75.160275
# 2  264.210040  74.064756
# 3  326.972183  95.059350
# 4  268.796360  47.015198

# %%
# Vamos plotar o gráfico
df_user_elo7.plot.scatter(x='tempo',y='ticket', alpha=0.5)
plt.xlabel('Tempo (s)')
plt.ylabel('Ticket (R$)')
plt.show()

# %%
from sklearn.cluster import KMeans

n_clusters = range(2,5)

for n in n_clusters:
    estimator = KMeans(n_clusters=n, random_state=170)
    estimator.fit(df_user_elo7.values)
    labels = estimator.labels_
    plt.scatter(x=df_user_elo7.values[:,0],
                y=df_user_elo7.values[:,1],
                c=labels.astype(np.float),
                cmap='rainbow',
                edgecolor='k')
    plt.title('Num clusters: {}'.format(n))
    plt.show()

# %%
df_user_elo7.var()
# Out:
# tempo     123372.183785
# ticket      1709.873526
# dtype: float64

# %%
# Vamos normalizar os dados!
from sklearn.preprocessing import StandardScaler

# %%
# E agora plotamos o resultado
n_clusters = range(2,5)

X = df_user_elo7.values

# Dados normalizados
X_scaled = StandardScaler().fit_transform(X)

for n in n_clusters:
    estimator = KMeans(n_clusters=n, random_state=170)
    estimator.fit(X_scaled)
    labels = estimator.labels_
    plt.scatter(x=X_scaled[:,0],
                y=X_scaled[:,1],
                c=labels.astype(np.float),
                cmap='rainbow',
                edgecolor='k')
    plt.title('Num clusters: {}'.format(n))
    plt.show()

# %%
# Range de valores de clusters que vamos testar
k = range(1,8,1)

# Lista de inércias
inertias = []

# Para cada valor de k, ache a inércia
for i in k:
    # crie a instância
    kmeans = KMeans(n_clusters=i)

    # Treine o modelo
    model = kmeans.fit(X_scaled)

    # Ache a inercia dos clusters
    inertias.append(model.inertia_)
    
plt.plot(k, inertias, '-ob')
plt.xlabel('Clusters')
plt.ylabel('Inertia')
plt.grid()
plt.show()

# %% [markdown]
# Podemos ver que o valor da inércia decresce rapidamente até *k*=3, mas depois decresce lentamente. Uma regra usual para a escolha do número de clusters é pegar exatamente esse valor de mudança de inclinação mais acentuada. De fato, ao escolhermos 3 clusters para o problema, nós poderíamos encontrar clusters bem separados.

# %% [markdown]
# ---
# ## Case Elo7 - Clustering de Frete
#
# Um dos problemas mais complicados do Elo7 é sua dependência dos correios. Nós sofremos muito com a falta de alternativas para dar aos nossos clientes (compradores e vendedores), já que o serviço dos correios além de caro, é também instável.
#
# Para tentar resolver esse problema, o time de Data Science do Elo7 foi chamado para tentar encontrar alguma alternativa. Após algumas conversas, nós levantamos a possibilidade de utilizarmos serviços de entrega independentes dos correios. Mas, o problema é que esses serviços necessitam de um volume grande de encomendas por ponto de coleta, o que não é o caso para a maioria dos vendedores cadastrados no Elo7.
#
# Uma possível solução seria encontrar pontos de coleta que pudessem agregar pedidos de vários vendedores e enviar de uma vez só com um desses serviços alternativos. Mas, como obtemos a localização desses pontos de coleta? Podemos aplicar um algoritmo de clustering nas rotas de frete mais frequentes!
#
# Vamos tentar analisar os dados e verificar o que conseguimos obter. O dataset a seguir contém pares de endereços de origem e destino de entregas realizadas apenas na cidade de São Paulo em um curto intervalo de tempo.

# %%
df_route = pd.read_csv(os.path.join(DATASET_FOLDER, 'route_clustering_elo7_dataset.csv'), sep=';')

df_route.head()
# Out:
#   cep_origem  latitude_origem  longitude_origem cep_destino  latitude_destino  \
# 0  02854-000       -23.458472        -46.697457   05661-000        -23.608533
# 1  04563-000       -23.610779        -46.685776   05410-000        -23.557603
# 2  08265-000       -23.572392        -46.452325   02976-000        -23.481036
# 3  04195-000       -23.656972        -46.613229   03426-000        -23.552227
# 4  02235-000       -23.479388        -46.581890   05036-000        -23.516369
#
#    longitude_destino
# 0         -46.729718
# 1         -46.676987
# 2         -46.715047
# 3         -46.537025
# 4         -46.690578

# %% [markdown]
# Para facilitar os cálculos de distância, as latitudes e longitudes dos locais já foram realizados.

# %% [markdown]
# Vamos agora formar nosso vetor de features contendo as posições geográficas das nossas rotas.

# %%
X = df_route[['latitude_origem','longitude_origem','latitude_destino','longitude_destino']].values

# %% [markdown]
# Precisamos normalizar os dados.

# %%
X_scaled = StandardScaler().fit_transform(X)

# %%
df_route[['latitude_origem','longitude_origem','latitude_destino','longitude_destino']].var()
# Out:
# latitude_origem      0.004914
# longitude_origem     0.008277
# latitude_destino     0.003999
# longitude_destino    0.006226
# dtype: float64

# %% [markdown]
# Quantos clusters vamos utilizar? Podemos aplicar o método do cotovelo para descobrir.

# %%
# Range de valores de clusters que vamos testar
k = range(1,10,1)

# Lista de inércias
inertias = []

# Para cada valor de k, ache a inércia
for i in k:
    # crie a instância
    kmeans = KMeans(n_clusters=i)

    # Treine o modelo
    model = kmeans.fit(X_scaled)

    # Ache a inercia dos clusters
    inertias.append(model.inertia_)
    
plt.plot(k, inertias, '-ob')
plt.xlabel('Clusters')
plt.ylabel('Inertia')
plt.grid()
plt.show()

# %% [markdown]
# Agora podemos iniciar o algoritmo de clustering.

# %%
kmeans = KMeans(n_clusters=5)

# %%
labels = kmeans.fit_predict(X_scaled)

# %% [markdown]
# A análise da quantidade de ítens em cada cluster é sempre uma boa prática. Clusters desbalanceados é um sinal de que os dados não foram bem separados.

# %%
label, count = np.unique(labels, return_counts=True)
for l, c in zip(label,count):
    print('Cluster {}: {}'.format(l,c))
# Out:
# Cluster 0: 879
# Cluster 1: 823
# Cluster 2: 887
# Cluster 3: 711
# Cluster 4: 837

# %% [markdown]
# Vamos ver os gráficos para analisar qualitativamente os resultados.

# %%
labels = kmeans.labels_

ax1 = plt.subplot(1,2,1)
ax1.set_title('Origem')
plt.scatter(x=X[:,0],
            y=X[:,1],
            c=labels, 
            edgecolor='k',
            cmap='rainbow')
ax1.set_xlim((-23.4,-23.9))

ax2 = plt.subplot(1,2,2)
ax2.set_title('Destino')
plt.scatter(x=X[:,2],
            y=X[:,3],
            c=labels, 
            edgecolor='k',
            cmap='rainbow')
ax2.set_xlim((-23.4,-23.9))

plt.show()

# %% [markdown]
# O que achou? É possível perceber clusters bem definidos? Será que podemos utilizar esses clusters para resolver nossos problemas de frete?

# %% [markdown]
# ---
# # DBSCAN
#
#
# #### Perfil usuários Elo7
# Vamos ver como ficaria o exemplo dos usuários do Elo7 utilizando DBSCAN.

# %%
from sklearn.cluster import DBSCAN

X = df_user_elo7.values

# Dados normalizados
X_scaled = StandardScaler().fit_transform(X)

estimator = DBSCAN(eps=0.33, min_samples=10, metric='euclidean')

estimator.fit(X_scaled)

labels = estimator.labels_
plt.scatter(x=X[:,0],
            y=X[:,1],
            c=labels, 
            edgecolor='k',
            cmap='rainbow')
plt.show()
print(np.unique(labels))
# Out:
# [-1  0  1  2]

# %% [markdown]
# #### Clustering Rotas Frete

# %%
dbscan = DBSCAN(eps=0.53, min_samples=30, metric='euclidean')

X = df_route[['latitude_origem','longitude_origem','latitude_destino','longitude_destino']].values

X_scaled = StandardScaler().fit_transform(X)

labels = dbscan.fit_predict(X_scaled)

ax1 = plt.subplot(1,2,1)
ax1.set_title('Origem')
plt.scatter(x=X[:,0],
            y=X[:,1],
            c=labels, 
            edgecolor='k',
            cmap='rainbow')
ax1.set_xlim((-23.4,-23.9))

ax2 = plt.subplot(1,2,2)
ax2.set_title('Destino')
plt.scatter(x=X[:,2],
            y=X[:,3],
            c=labels, 
            edgecolor='k',
            cmap='rainbow')
ax2.set_xlim((-23.4,-23.9))

ax1.legend(labels)
plt.show()

print(np.unique(dbscan.labels_))
# Out:
# [-1  0  1  2]

# %% [markdown]
# ---
# ## Hierarchical Clustering
#
# Vamos agora aprender sobre outro método de clustering: [**Hierarchical Clustering**](https://en.wikipedia.org/wiki/Hierarchical_clustering). Como o nome mesmo diz, ele utiliza o conceito de *hierarquia* para construir os clusters. Existem duas principais variações do algoritmo: aglomerativo e por divisão. O primeiro é mais usado na prática. O passo a passo do algoritmo é apresentado abaixo:
#
# - Primeiro colocamos todos as observações em clusters próprios;
# - Depois, iterativamente procuramos os clusters mais próximos\* e agrupamos eles em um novo cluster;
# - Repetimos o passo anterior até formarmos um único cluster com todas as observações.
#
# \*Obs: A definição de distância (ou similaridade) entre clusters depende do tipo de métrica de distância (Euclidiana, Manhattan, cosseno etc) e ligação (Ward, simples, completa etc).
#
# Como podemos ver no algoritmo, o objetivo é a criação de um grande cluster que agrupe todos os dados. Nós podemos visualizar esse histórico de agrupamentos a partir de um [dendrograma](https://en.wikipedia.org/wiki/Dendrogram). A então criação de clusters mais granulares depende da região de similaridade que se deseja realizar o corte.

# %% [markdown]
# ---
# ### Exercício prático Hierarchical Clustering
#
# Vamos praticar agora!
# Utilizaremos o dataset do [Eurovision de 2016](https://eurovision.tv/history/full-split-results) para essa tarefa. Esse evento é uma competição de músicas entre países. Cada país participante seleciona uma música para concorrer com as outras. Ao final, cada país deve votar nas músicas com pontuações entre [1,2,3,4,5,6,7,8,10,12]. Um país pode votar tanto através de um juri formado oficialmente pelo país ou via votos por telefone. Ao final, ganha o país que receber a maior quantidade de pontos.
#
# Essa competição é famosa por apresentar um comportamento indesejado: os países próximos geografica e culturalmente tendem a se favorecer. Por essa razão há sempre mudanças nas regras para tentar evitar que isso aconteça. Será que conseguiremos perceber esse comportamento através de um algoritmo de clustering? Vamos tentar!
#
# Um país não pode votar em si próprio, mas, para podermos fazer a nossa análise, considerei que um país daria a pontuação máxima (12) para ele próprio.
#
# As colunas do dataset são descritas a seguir e consideramos apenas votos feitos por telefone:
#
# - `From country`: País votante
# - `Televote Points`: Pontuação dada por telefone pelo país votante
# - `To country`: País que recebeu a pontuação do país votante
#
# ![Eurovision](https://www.eurovisionary.com/wp-content/uploads/2015/11/eurovision-2016.jpg)

# %%
# Vamos iniciar a leitura do dataset
df_euro = pd.read_csv(os.path.join(DATASET_FOLDER, 'eurovision_dataset.csv'), sep=';')

df_euro.head(10)
# Out:
#   From country  Televote Points      To country
# 0      Albania              2.0         Armenia
# 1      Albania             12.0       Australia
# 2      Albania              0.0         Austria
# 3      Albania              0.0      Azerbaijan
# 4      Albania              0.0         Belgium
# 5      Albania              8.0        Bulgaria
# 6      Albania              0.0         Croatia
# 7      Albania              0.0          Cyprus
# 8      Albania              0.0  Czech Republic
# 9      Albania              0.0          France

# %%
# Podemos visualizar quem está ganhando nessa votação
df_euro_points = df_euro.groupby(['To country']).sum()
df_euro_points.sort_values(by='Televote Points', inplace=True, ascending=False)
df_euro_points.head(10)
# Out:
#             Televote Points
# To country
# Russia                373.0
# Ukraine               335.0
# Poland                234.0
# Australia             203.0
# Bulgaria              192.0
# Sweden                151.0
# Armenia               146.0
# Austria               132.0
# France                121.0
# Lithuania             108.0

# %% [markdown]
# Se formos considerar apenas os votos por telefone, a Russia está ganhando a competição!

# %% [markdown]
# Como fizemos para o exercício anterior, nós temos que tomar cuidado com a distribuição dos dados. como temos valores discretos e determinísticos de pontuação, não faz sentido analisarmos a variância dos dados. Entretanto, podemos normalizar os pontos em uma escala de 0-100%.

# %%
# Obtenha o vetor de pontos
X = np.array([i for i in df_euro.groupby('From country')['Televote Points'].apply(np.array)])

# TODO
# Realize a normalização dos dados
# Dica: Procure por MaxAbsScaler no scikit-learn
from sklearn.preprocessing import MaxAbsScaler

normalizer = MaxAbsScaler()

X_norm = normalizer.fit_transform(X)

# %% [markdown]
# Vamos realizar agora o algoritmo Hierarchical Clustering!

# %%
from sklearn.clustering.hierarchy import linkage, dendogram
# TODO
# Aplique o algoritmo Hierarchical Clustering utilizando o scipy
# Selecione uma métrica de distância e um método de ligação
# Teste vários para obter a intuição por trás de cada método
Y = linkage(X_norm, method='ward', metric='euclidean')
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-44-f7877dda346a> in <module>()
# ----> 1 from sklearn.clustering.hierarchy import linkage, dendogram
#       2 # TODO
#       3 # Aplique o algoritmo Hierarchical Clustering utilizando o scipy
#       4 # Selecione uma métrica de distância e um método de ligação
#       5 # Teste vários para obter a intuição por trás de cada método
#
# ModuleNotFoundError: No module named 'sklearn.clustering'

# %%
# TODO
# Crie o dendrograma para visualizar os resultados
# Será necessário obter os valores de labels que são os países
# *votantes* da competição (Dica: Procure pelo método unique do pandas)
plt.figure(figsize=(16,10))
labels = pd.unique(df_euro['From country'])
dendrogram(Y, 
           labels=labels, 
           leaf_rotation=90, 
           leaf_font_size=14) # Use o leaf_font_size = 14

plt.show()

# %% [markdown]
# O que podemos dizer sobre o dendrograma? Há alguma relação cultural, política ou geográfica entre os países? Se quiséssemos escolher uma região de corte para formar clusters intermediários, qual seria?

# %% [markdown]
# #### Exemplo Grãos (Opcional)
#
# Vamos utilizar o dataset de diferentes tipos de grãos de trigo obtidos pelo [UCI](https://archive.ics.uci.edu/ml/datasets/seeds#) para treinar esses conceitos.
#
# O dataset contém os seguintes parâmetros:
#
# - `area`: Área total do grão, A
# - `perimeter`: Perímetro do grão, P
# - `compactness`: Grão de compactação do grão - $C = \frac{4 \pi A}{P^2}$
# - `length_kernel`: Comprimento do núcleo
# - `width_kernel`: Largura do núcleo
# - `asymmetry`: Coeficiente de assimetria
# - `kernel_groove`: Comprimento do sulco do núcleo
#
# Variedades de grãos: 'Kama' (1), 'Rosa' (2) e 'Canadian' (3)

# %%
# Importar os dados
df_grain = pd.read_csv(os.path.join(DATASET_FOLDER, 'seeds_dataset.csv'), sep=';')
df_grain.head(5)
# Out:
#     area  perimeter  compactness  length_kernel  width_kernel  asymmetry  \
# 0  15.26      14.84       0.8710          5.763         3.312      2.221
# 1  14.88      14.57       0.8811          5.554         3.333      1.018
# 2  14.29      14.09       0.9050          5.291         3.337      2.699
# 3  13.84      13.94       0.8955          5.324         3.379      2.259
# 4  16.14      14.99       0.9034          5.658         3.562      1.355
#
#    kernel_groove varieties
# 0          5.220      Kama
# 1          4.956      Kama
# 2          4.825      Kama
# 3          4.805      Kama
# 4          5.175      Kama

# %% [markdown]
# Antes de iniciarmos o processo de clustering, vamos verificar se há muita discrepância entre as variâncias das features. Essa etapa é muito importante, porque features com variância elevada possuem maior influência na medida de distância do algoritmo do que features com menor variância, o que pode ser indesejado. Quando normalizamos as features, nós conseguimos dar influências iguais para todas elas.

# %%
df_grain.var()
# Out:
# area             8.466351
# perimeter        1.705528
# compactness      0.000558
# length_kernel    0.196305
# width_kernel     0.142668
# asymmetry        2.260684
# kernel_groove    0.241553
# dtype: float64

# %% [markdown]
# Percebemos que o atributo `area` possui maior variância, enquanto o `compactness` possui baixa variância. Portanto, vamos primeiramente normalizar as features utilizando o [`StandardScaler`](https://scikit-learn.org/stable/modules/generated/sklearn.preprocessing.StandardScaler.html) do scikit-learn. Ele normaliza as features individualmente deixando a variância delas igual a 1.

# %%
# Vamos importar o StandardScaler
from sklearn.preprocessing import StandardScaler

# %%
# Vamos criar agora o vetor de atributos
X = df_grain[['area','perimeter','compactness','length_kernel','width_kernel','asymmetry','kernel_groove']].values

# %%
# Agora precisamos normalizar o vetor de features

# Primeiro criamos uma instância do StandardScaler
normalizer = StandardScaler()

# Agora podemos normalizar através do método fit_transform
X_norm = normalizer.fit_transform(X)

# Podemos verificar que a variância de cada feature é 1
np.var(X_norm, axis=0)
# Out:
# array([ 1.,  1.,  1.,  1.,  1.,  1.,  1.])

# %% [markdown]
# O scikit-learn possui um método próprio para o algoritmo de [Hierarchical Clustering](http://scikit-learn.org/stable/modules/generated/sklearn.cluster.AgglomerativeClustering.html#sklearn.cluster.AgglomerativeClustering). Entretanto, ele não nos permite visualizar facilmente o dendrograma final. Por isso, vamos utilizar a versão do scipy.

# %%
# Importe os métodos linkage (Hierarchical Clustering) e dendrogram
from scipy.cluster.hierarchy import linkage, dendrogram

# %%
# Vamos escolher a métrica de distância:
distance = 'euclidean'
# Agora o tipo de ligação
linkage_type = 'complete'

# Vamos aplicar o método linkage
Y = linkage(X_norm, method=linkage_type, metric=distance)

# %%
Y.shape
# Out:
# (209, 4)

# %%
# Agora estamos prontos para plotar o dendrograma
# Vamos obter o nome das variedades dos grãos
varieties = df_grain['varieties'].values

# Construímos finalmente o dendrograma
plt.figure(figsize=(16,10))
dendrogram(Y,
           labels=varieties,
           leaf_rotation=90,
           leaf_font_size=6,
)
plt.show()

# %% [markdown]
# Podemos notar que os clusters formados a partir do Hierarchical Clustering fazem bastante sentido com relação às variedades dos grãos de trigo. Vamos realizar agora um corte no dendrograma de forma a ficarmos com apenas 3 clusters, que representa uma distância de 6.

# %% [markdown]
# Para essa tarefa nós podemos usar o método [`fcluster`](https://docs.scipy.org/doc/scipy-0.14.0/reference/generated/scipy.cluster.hierarchy.fcluster.html) do scipy. Ele nos permite realizar um corte na árvore de clustering gerada pelo Hierarchical Clustering.

# %%
from scipy.cluster.hierarchy import fcluster

# %%
# Vamos gerar os rótulos para os clustes
num_clusters = 3
labels = fcluster(Y, num_clusters ,criterion='maxclust')

# %%
labels[:10]
# Out:
# array([2, 2, 2, 2, 2, 2, 2, 2, 1, 2], dtype=int32)

# %%
# Vamos agora criar um dataframe para podermos utilizar o cross-tabulation do pandas
df = pd.DataFrame({'labels': labels, 'varieties': varieties})

# Crie a matriz de tabulação cruzada
ct = pd.crosstab(df['labels'], df['varieties'])

print(ct)
# Out:
# varieties  Canadian  Kama  Rosa
# labels
# 1                 0     2    66
# 2                 0    48     4
# 3                70    20     0

# %% [markdown]
# Podemos notar que o as variedades Canadian e Rosa foram muito bem agrupados nos clusters, mas a Kama não teve o mesmo sucesso. Vamos tentar utilizar o método "Ward" para a ligação e ver se há alguma variação.

# %%
# Distância
distance = 'euclidean'
# Ligação
linkage_type = 'ward'

# Treinar modelo Hierarchical Clustering
Y = linkage(X_norm, method=linkage_type, metric=distance)

# Plota dendrograma
plt.figure(figsize=(16,10))
dendrogram(Y,
           labels=varieties,
           leaf_rotation=90,
           leaf_font_size=6,
)
plt.show()

# Número de clusters
num_clusters = 3

# Obtem labels
labels = fcluster(Y, num_clusters ,criterion='maxclust')

# Vamos agora criar um dataframe para podermos utilizar o cross-tabulation do pandas
df = pd.DataFrame({'labels': labels, 'varieties': varieties})

# Crie a matriz de tabulação cruzada
ct = pd.crosstab(df['labels'], df['varieties'])

print(ct)
# Out:
# varieties  Canadian  Kama  Rosa
# labels
# 1                 0     4    66
# 2                65     2     0
# 3                 5    64     4

# %% [markdown]
# Agora temos um resultado melhor para a variedade Kama, mas piorou um pouco o resultado para a Canadian. Dificilmente teremos um algoritmo que consegue ser perfeito em todos os casos. Mas, como podemos visualizar no dendrograma e na matriz de tabulação cruzada, nós conseguimos um bom resultado de clusterização.

# %% [markdown]
# ---
# ## Comparação métodos clustering:
# ### K-Means x Hierarchical Clustering x DBSCAN

# %% [markdown]
# Vamos testar os 3 algoritmos utilizando alguns datasets padrão do scikit-learn.

# %%
from sklearn import cluster, datasets, mixture
from sklearn.neighbors import kneighbors_graph
from sklearn.preprocessing import StandardScaler
from itertools import cycle, islice

np.random.seed(0)

# ============
# Gera os dados
# ============
n_samples = 1500
# Circulos concentricos
noisy_circles = datasets.make_circles(n_samples=n_samples, factor=.5,
                                      noise=.05)
# Formato de lua
noisy_moons = datasets.make_moons(n_samples=n_samples, noise=.05)
# Bolas
blobs = datasets.make_blobs(n_samples=n_samples, random_state=8)
# Sem estrutura (uniforme)
no_structure = np.random.rand(n_samples, 2), None

# Dados distribuídos anisotropicamente
random_state = 170
X, y = datasets.make_blobs(n_samples=n_samples, random_state=random_state)
transformation = [[0.6, -0.6], [-0.4, 0.8]]
X_aniso = np.dot(X, transformation)
aniso = (X_aniso, y)

# blobs with varied variances
varied = datasets.make_blobs(n_samples=n_samples,
                             cluster_std=[1.0, 2.5, 0.5],
                             random_state=random_state)

# ============
# Ajusta os parametros dos modelos e datasets
# ============
plt.figure(figsize=(16, 20))
plt.subplots_adjust(left=.02, right=.98, bottom=.001, top=.96, wspace=.05,
                    hspace=.01)

plot_num = 1

# Parametros dos modelos de clustering
default_base = {'quantile': .3,
                'eps': .3,
                'damping': .9,
                'preference': -200,
                'n_neighbors': 10,
                'n_clusters': 3}

# Parametros do dataset
datasets = [
    (noisy_circles, {'damping': .77, 'preference': -240,
                     'quantile': .2, 'n_clusters': 2}),
    (noisy_moons, {'damping': .75, 'preference': -220, 'n_clusters': 2}),
    (varied, {'eps': .18, 'n_neighbors': 2}),
    (aniso, {'eps': .15, 'n_neighbors': 2}),
    (blobs, {}),
    (no_structure, {})]

for i_dataset, (dataset, algo_params) in enumerate(datasets):
    # Atualiza os parametros para o dataset especifico
    params = default_base.copy()
    params.update(algo_params)

    X, y = dataset

    # Normaliza o dataset
    X = StandardScaler().fit_transform(X)

    # ============
    # Criação dos objetos de clustering
    # ============
    
    # K-Means
    two_means = cluster.KMeans(n_clusters=params['n_clusters'])
    
    # DBSCAN
    dbscan = cluster.DBSCAN(eps=params['eps'])
    
    # Hierarchical Clustering - Aglomerativo
    ward = cluster.AgglomerativeClustering(
        linkage="ward",
        n_clusters=params['n_clusters'])

    clustering_algorithms = (
        ('KMeans', two_means),
        ('HierarchicalClustering', ward),
        ('DBSCAN', dbscan),
    )

    for name, algorithm in clustering_algorithms:
        algorithm.fit(X)

        if hasattr(algorithm, 'labels_'):
            y_pred = algorithm.labels_.astype(np.int)
        else:
            y_pred = algorithm.predict(X)

        plt.subplot(len(datasets), len(clustering_algorithms), plot_num)
        if i_dataset == 0:
            plt.title(name, size=18)

        colors = np.array(list(islice(cycle(['#377eb8', '#ff7f00', '#4daf4a',
                                             '#f781bf', '#a65628', '#984ea3',
                                             '#999999', '#e41a1c', '#dede00']),
                                      int(max(y_pred) + 1))))
        plt.scatter(X[:, 0], X[:, 1], s=10, color=colors[y_pred])

        plt.xlim(-2.5, 2.5)
        plt.ylim(-2.5, 2.5)
        plt.xticks(())
        plt.yticks(())
        plot_num += 1

plt.show()

# %% [markdown]
# ---
# # Case Elo7 - Motivos de Compra
#
# Os compradores do Elo7 são incentivados a indicar o motivo da compra de determinado produto no seu marketplace. Esses motivos nos ajudam a entender melhor o **momento** de compra do usuário. O dataset apresentado a seguir contém um subset desses motivos de compra.

# %%
df_reason = pd.read_csv(os.path.join(DATASET_FOLDER, 'purchase_reason_elo7_dataset.csv'), sep=';')

df_reason.head(10)
# Out:
#                               product_title  \
# 0          apliques recortados fundo do mar
# 1            mini raposa vermelha amigurumi
# 2                 o pequeno principe i bata
# 3        quadro maternidade menino elefante
# 4            livro de votos casamento o par
# 5       caixa 40 charuto de chocolate belga
# 6            arquivo de corte vamos brindar
# 7    prateleira com varao mdf reta 96x20x14
# 8                     colherzinha bailarina
# 9  caixa cone arvore jardim dos passarinhos
#
#                                reason
# 0        festa de 2 anos do meu filho
# 1                   presente para mim
# 2                         aniversario
# 3              nascimento do meu bebe
# 4                           casamento
# 5            lembranca de maternidade
# 6                       mimo para mim
# 7  decoracao do quarto da minha filha
# 8                         aniversario
# 9                               festa

# %% [markdown]
# Existem muitos tipos possíveis de motivos de compra, mas será que nós podemos encontrar algum padrão neles? Me parece um problema clássico de **clustering**.

# %% [markdown]
# Vamos utilizar o Tf-Idf para criar o embedding dos motivos de compra e o K-Means para encontrar clusters.

# %%
from sklearn.feature_extraction.text import TfidfVectorizer

tfidf = TfidfVectorizer(max_df=0.9, max_features=5000, sublinear_tf=True, use_idf=True)

# %% [markdown]
# Cria a matriz de embeddings.

# %%
X = tfidf.fit_transform(df_reason['reason'].values)

# %% [markdown]
# Como escolher o número de clusters? Vamos utilizar o gráfico de inércias. (Obs: outra possibilidade é avaliar o ["silhouette score"](http://scikit-learn.org/stable/auto_examples/cluster/plot_kmeans_silhouette_analysis.html#sphx-glr-auto-examples-cluster-plot-kmeans-silhouette-analysis-py)).

# %%
# Range de valores de clusters que vamos testar
k = range(10,200,20)

# Lista de inércias
inertias = []

# Para cada valor de k, ache a inércia
for i in k:
    # crie a instância
    kmeans = KMeans(n_clusters=i)

    # Treine o modelo
    model = kmeans.fit(X)

    # Ache a inercia dos clusters
    inertias.append(model.inertia_)
    
plt.plot(k, inertias, '-ob')
plt.xlabel('Clusters')
plt.ylabel('Inertia')
plt.grid()
plt.show()

# %% [markdown]
# Inicializa o K-Means com a quantidade de clusters que escolhemos a partir do gráfico.

# %%
kmeans = KMeans(n_clusters=50)

# %% [markdown]
# Treina o modelo K-Means.

# %%
kmeans.fit(X)
# Out:
# KMeans(algorithm='auto', copy_x=True, init='k-means++', max_iter=300,
#     n_clusters=50, n_init=10, n_jobs=1, precompute_distances='auto',
#     random_state=None, tol=0.0001, verbose=0)

# %% [markdown]
# Encontra os clusters para cada motivo de compra.

# %%
labels = kmeans.predict(X)

# %% [markdown]
# Vamos agora visualizar os clusters criados.

# %%
# Crie um novo dataframe com os labels dos clusters
df = pd.DataFrame({'reason': df_reason['reason'], 'labels': labels})

df.head()
# Out:
#    labels                        reason
# 0      12  festa de 2 anos do meu filho
# 1      27             presente para mim
# 2       0                   aniversario
# 3      37        nascimento do meu bebe
# 4       2                     casamento

# %% [markdown]
# Vamos verificar a distribuição de motivos em cada cluster. Quanto mais desbalanceado, pior.

# %%
df.groupby('labels').size()
# Out:
# labels
# 0     8874
# 1     6361
# 2     6254
# 3     6961
# 4     1298
# 5      475
# 6      349
# 7     1582
# 8     2082
# 9     1750
# 10    2086
# 11     613
# 12    1057
# 13    1326
# 14      98
# 15    2024
# 16    3232
# 17     740
# 18     614
# 19    1737
# 20    1281
# 21    2195
# 22     551
# 23    2625
# 24    1304
# 25     610
# 26    1066
# 27    2411
# 28    1344
# 29    5607
# 30    1003
# 31    1643
# 32    1684
# 33    1281
# 34    2361
# 35     213
# 36    8272
# 37     928
# 38    1428
# 39     437
# 40     659
# 41     929
# 42    1421
# 43    1353
# 44     674
# 45     462
# 46    1590
# 47    1839
# 48    1360
# 49    1956
# dtype: int64

# %% [markdown]
# Podemos visualizar alguns exemplos de clusters gerados pelo K-Means.

# %%
for idx in range(50):
    idx_labels = df[df['labels']==idx]['reason'].unique()
    print('- Cluster {}:'.format(idx + 1))
    for i in np.random.choice(idx_labels, min(len(idx_labels), 10), replace=False):
        print(' '*5, i)
    print()
# Out:
# - Cluster 1:
#       aniversario
#       para aniversario
#
# - Cluster 2:
#       presente
#       meu presente
#       presente aniversario
#
# - Cluster 3:
#       aniversario de casamento
#       para o casamento
#       casamento filha
#       para casamento
#       presente de casamento
#       presente casamento
#       casamento
#
# - Cluster 4:
#       aniversario minha filha
#       vestido para o aniversario da minha filha
#       aniversario de minha filha
#       para festa de aniversario da minha filha
#       chegada da minha filha
#       para decorar o quarto da minha filha
#       decoracao para festa da minha filha
#       lembrancinha para a festa da minha filha
#       aniversario de 5 anos da minha filha
#       aniversario da minha filha 2 anos
#
# - Cluster 5:
#       mimo p mim
#       um mimo
#       mimo para minha cozinha
#       mimo para filha
#       mimo para meu casamento
#       mimo p mim mesma
#       meu mimo
#       um mimo para mim mesma
#       mimo pra mim mesma
#       mimo para eu mesma
#
# - Cluster 6:
#       pra meu uso
#       uso particular
#       para uso no trabalho
#       para uso
#       para meu uso
#       para uso escolar
#       para o meu uso
#       para uso profissional
#       para meu uso mesmo
#       uso
#
# - Cluster 7:
#       aniversario do filhote
#       aniver do filho
#       aniversario do filho
#       aniversario do neto
#       quarto do filho
#       aniversario do meu filhote
#
# - Cluster 8:
#       lembranca aniversario filha
#       lembranca formatura
#       lembranca de niver
#       lembranca para festa
#       lembranca para casamento
#       lembranca casamento
#       lembranca madrinhas
#       lembranca para aniversario
#       lembranca de festa
#       lembranca
#
# - Cluster 9:
#       trabalho de escola
#       para meu trabalho
#       material para trabalho
#       uso trabalho
#       material para meu trabalho
#       meu trabalho
#       para o trabalho
#       trabalho escolar
#       trabalho
#       para trabalho
#
# - Cluster 10:
#       mimos pra mim
#       presente pra minha mae
#       pra mim msm
#       presente pra minha namorada
#       presente pra minha bebe
#       pra mim mesmo
#       presente pra minha neta
#       um presente pra mim mesma
#       pra mim
#       comprei pra mim mesma
#
# - Cluster 11:
#       decoracao da festa
#       decoracao quarto meu filho
#       decoracao de quarto de bebe
#       decoracao de festa
#       decoracao para festa
#       decoracao quarto bebe
#       decoracao de mesa
#       decoracao de quarto
#       decoracao para aniversario
#       decoracao
#
# - Cluster 12:
#       uma ocasiao especial
#       uma ocasiao especial aniversario da minha filha
#       uma ocasiao
#       uma ocasiao especial meu casamento
#       uma ocasiao muito especial
#       para uma ocasiao especial
#
# - Cluster 13:
#       festa de 1 aninho do meu filho
#       lembrancinha para festa do meu filho
#       para festa do meu filho
#       festa de 3 anos do meu filho
#       festa do meu neto
#       festa de 2 anos do meu filho
#       para festa de aniversario do meu filho
#       festa do meu pequeno
#       festa filho
#       festa do meu filhote
#
# - Cluster 14:
#       convite dos padrinhos
#       convite
#       convite padrinhos
#       convite para meus padrinhos de casamento
#       convite de formatura
#       convite para padrinhos de batismo
#       convite para festa
#       meu convite de casamento
#       convite padrinhos de casamento
#       convite aniversario meu filho
#
# - Cluster 15:
#       lembrancinha de cha de fraldas
#       lembrancinha do cha de bebe
#       lembrancinha cha de fraldas
#       lembrancinha para cha de bebe
#       lembrancinha cha de bebe
#       lembrancinha de cha de bebe
#
# - Cluster 16:
#       lembrancinha para festa de aniversario
#       lembrancinha aniversario filha
#       para lembrancinha de aniversario
#       lembrancinha para padrinhos
#       lembrancinha festa de aniversario
#       lembrancinha para madrinhas
#       lembrancinha
#       lembrancinha de 15 anos
#       lembrancinha de pascoa
#       lembrancinha aniversario filho
#
# - Cluster 17:
#       presente para noiva
#       gravatas para padrinhos de casamento
#       caixa para padrinhos
#       presente para os filhos
#       presente padrinhos de casamento
#       presente para os padrinhos do meu filho
#       presente para o meu marido
#       um presente
#       presente para eu mesma
#       presente para o noivo
#
# - Cluster 18:
#       pessoal
#       compra pessoal
#       organizacao pessoal
#       necessidade pessoal
#       presente pessoal
#       arquivo pessoal
#       mimo pessoal
#
# - Cluster 19:
#       decoracao de natal
#       decoracao natal
#       festa de natal
#       enfeites de natal
#       presente natal
#       enfeite de natal
#       lembrancas de natal
#       lembranca natal
#       presente para o natal
#       meu presente de natal
#
# - Cluster 20:
#       festa de 15 anos da minha filha
#       aniversario de 15 anos de minha filha
#       festa de familia
#       aniversario de 15 anos
#       festa de aniversario de meu filho
#       festa de cliente
#       lembrancinha de festa de aniversario
#       festa de noivado
#       aniversario de 4 anos
#       festa de 15 anos
#
# - Cluster 21:
#       uso proprio e presente
#       para meu proprio uso
#       proprio uso
#       compra para uso proprio
#       presente e uso proprio
#       pra uso proprio
#       para uso proprio
#       uso proprio
#       proprio
#       comprei para uso proprio
#
# - Cluster 22:
#       presente para minha filha
#       um presente para minha filha
#       presente para o quarto da minha filha
#       mimo para minha filha
#       minha
#       presente de aniversario para minha filha
#       casamento minha filha
#       para mim e minha filha
#       comprei para minha filha
#       festa minha filha
#
# - Cluster 23:
#       amiga
#       presente para o bebe de uma amiga
#       presentear uma amiga
#       presente amiga
#       presente para uma amiga gravida
#       presente para uma amiga querida
#       presente de aniversario para uma amiga
#       presente para minha amiga
#       presente para uma grande amiga
#       presente para o filho de uma amiga
#
# - Cluster 24:
#       meu cha de cozinha
#       cha de bebe
#       meu cha de bebe
#       cha bebe
#       lembrancinhas cha de bebe
#       cha de bebe de uma amiga
#       cha de bebe da minha princesa
#       para meu cha de bebe
#       decoracao cha de bebe
#       cha de bebe do meu afilhado
#
# - Cluster 25:
#       batizado da minha filha
#       presente de batizado
#       batizado
#       presente para batizado
#       batizado minha filha
#       batizado filho
#       lembrancas de batizado
#       para o batizado da minha filha
#       convite batizado
#       batizado de minha filha
#
# - Cluster 26:
#       um presente para minha sobrinha
#       presente sobrinha
#       aniversario de 1 ano da minha sobrinha
#       aniversario minha sobrinha
#       presente para uma sobrinha
#       aniversario de minha sobrinha
#       presente pra sobrinha
#       minha sobrinha
#       15 anos da minha sobrinha
#       batizado da minha sobrinha
#
# - Cluster 27:
#       presente para um principe
#       convite do meu principe
#       para festa do meu principe
#       presente do meu principe
#       presente p meu principe
#       nascimento do meu principe
#       batizado do meu principe
#       chegada do meu principe
#       aniversario de 1 ano do meu principe
#       quarto do meu principe
#
# - Cluster 28:
#       para mim mesmo
#       um presente para mim
#       p mim
#       presente p mim
#       presente para mim mesmo
#       comprei para mim
#       mim mesmo
#       presente para mim
#       comprei para mim mesmo
#       compra para mim
#
# - Cluster 29:
#       niver 2 anos
#       niver filhos
#       niver da minha filhota
#       niver do neto
#       para niver do meu filho
#       niver de minha filha
#       niver 1 ano
#       niver da filha
#       niver meu filho
#       niver 15 anos
#
# - Cluster 30:
#       aniversario do meu filho
#       convite do meu filho
#       aniversario 2 anos do meu filho
#       lembranca de aniversario do meu filho
#       quartinho do meu filho
#       lembrancinha do meu filho
#       para o quartinho do meu filho
#       lembrancas de aniversario do meu filho
#       presente do meu filho
#       convite de aniversario do meu filho
#
# - Cluster 31:
#       aniversario dos meus netos
#       dia a dia
#       presente do dia dos pais
#       presente para dia dos professores
#       para os meus filhos
#       presente de dia dos pais
#       presente dia dos namorados
#       lembrancinha de aniversario dos meus filhos
#       aniversario dos meus filhos
#       filhos
#
# - Cluster 32:
#       compra para uso pessoal
#       para uso pessoal
#       comprei para uso pessoal
#       presente e uso pessoal
#       pra uso pessoal
#       uso pessoal e presente
#       para meu uso pessoal
#       uso pessoal
#
# - Cluster 33:
#       para nossa casa
#       decoracao em casa
#       cha de casa nova
#       enfeitar a casa
#       presente para a minha casa
#       para decorar a casa
#       para minha casa nova
#       para casa nova
#       compra para minha casa
#       enfeite para casa
#
# - Cluster 34:
#       lembranca de maternidade da minha filha
#       porta de maternidade
#       enfeite porta maternidade
#       lembrancinha maternidade
#       quadro de maternidade
#       kit maternidade
#       lembrancas maternidade
#       enfeite porta de maternidade
#       enfeite de maternidade
#       lembranca para maternidade
#
# - Cluster 35:
#       presente para meu bebe
#       para o quartinho da minha bebe
#       bebe
#       quartinho do bebe
#       para o quarto do bebe
#       quartinho do meu bebe
#       decoracao quarto do bebe
#       aniversario de 1 aninho do meu bebe
#       presente para minha bebe
#       quarto da bebe
#
# - Cluster 36:
#       presentes para padrinhos
#       presentes para mim
#       presentes
#       presentes de natal
#       presentes para amigas
#
# - Cluster 37:
#       consultorio
#       confeccao de personalizados
#       aniversario do miguel
#       casamento civil
#       material escolar do meu filho
#       locacao
#       sim aniversario
#       para escola
#       quarto das minhas filhas
#       aniversario das minhas princesas
#
# - Cluster 38:
#       nascimento de minha filha
#       nascimento do meu baby
#       nascimento minha filha
#       para o nascimento da minha filha
#       nascimento do meu neto
#       nascimento da filha
#       lembrancinhas nascimento
#       nascimento meu filho
#       nascimento do meu primeiro filho
#       lembrancinha nascimento
#
# - Cluster 39:
#       ocasiao especial meu casamento
#       um ocasiao especial
#       ocasiao muito especial
#       nenhuma ocasiao especial
#       especial
#       presente especial
#       ocasiao especial aniversario
#       ocasiao
#       ocasiao especial casamento
#       ocasiao especial
#
# - Cluster 40:
#       para artesanato
#       faco artesanato
#       material para artesanato
#       trabalho com artesanato
#       para fazer artesanato
#       fazer artesanato
#       artesanato
#       confeccao de artesanato
#       uso em artesanato
#       para meu artesanato
#
# - Cluster 41:
#       quarto filho
#       aniversario filho
#       presente filho
#       aniversario de filho
#       filho
#
# - Cluster 42:
#       lembrancinhas para o meu casamento
#       lembrancinhas para casamento
#       lembrancinhas da minha filha
#       fazer lembrancinhas
#       lembrancinhas maternidade
#       lembrancinhas para aniversario
#       lembrancinhas
#       lembrancinhas para aniversario do meu filho
#       lembrancinhas do meu casamento
#       lembrancinhas casamento
#
# - Cluster 43:
#       mimos para mim mesma
#       p mim mesma
#       um presente para mim mesma
#       mim mesma
#       foi para mim mesma
#       para eu mesma
#       para mim mesma
#       presente p mim mesma
#       presente para mim mesma
#       comprei para mim mesma
#
# - Cluster 44:
#       p meu filho
#       um presente para meu filho
#       presente pra meu filho
#       presente meu filho
#       presente para o quarto do meu filho
#       presente para meu filho
#       presente p meu filho
#       fantasia para meu filho
#       meu filho
#       quarto meu filho
#
# - Cluster 45:
#       aniversario infantil
#       decoracao infantil
#       festa de aniversario infantil
#       lembrancinha aniversario infantil
#       lembranca de festa infantil
#       lembrancinha festa infantil
#       decoracao quarto infantil
#       decoracao para festa infantil
#       decoracao de quarto infantil
#       lembrancinha de aniversario infantil
#
# - Cluster 46:
#       presente para meu sobrinho
#       festa sobrinho
#       aniversario sobrinho
#       niver sobrinho
#       niver do sobrinho
#       aniversario do meu sobrinho
#       presente para o meu sobrinho
#       presente para sobrinho
#       aniversario do sobrinho
#       sobrinho
#
# - Cluster 47:
#       aniver da minha princesa
#       aniversario da minha princesa
#       para festa da minha princesa
#       lembranca de aniversario da minha princesa
#       minha princesa
#       decoracao quarto da minha princesa
#       aniversario de 1 aninho da minha princesa
#       enxoval da minha princesa
#       para aniversario da minha princesa
#       festa da princesa
#
# - Cluster 48:
#       festa
#       para minha festa
#       festa aniversario
#       para uma festa
#       festa casamento
#       festa aniversario filha
#       para festa
#       uma festa
#       festa 2 anos
#       festa filha
#
# - Cluster 49:
#       1 ano do meu filho
#       festa de aniversario de 1 ano
#       aniversario de 1 ano do meu filho
#       lembranca de 1 ano
#       aniversario de 01 ano
#       aniversario de 1 ano da minha bebe
#       aniversario de 1 ano
#       lembrancinha 1 ano
#       aniversario de 01 ano do meu filho
#       aniversario de 1 ano da minha neta
#
# - Cluster 50:
#       comprei para meu casamento
#       pro meu casamento
#       lembrancinha para meu casamento
#       lembrancas para meu casamento
#       comprei para o meu casamento
#       lembrancas do meu casamento
#       para o meu casamento
#       lembrancinha do meu casamento
#       para meu casamento
#       convites para o meu casamento

# %% [markdown]
# Vamos verificar agora se existe alguma hierarquia entre os clusters.

# %%
from scipy.cluster.hierarchy import linkage, dendrogram, fcluster

Y = linkage(kmeans.cluster_centers_, method='ward', metric='euclidean')

# %%
titles = df.groupby('labels').apply(lambda x: np.random.choice(list(x['reason'])))

# %%
plt.figure(figsize=(16,10))
dendrogram(Y,
           labels=titles.values,
           leaf_rotation=90,
           leaf_font_size=14,
)
plt.show()

# %% [markdown]
# Podemos ver que há uma hierarquia entre os clusters. Poderíamos usar os métodos apresentados anteriormente para agrupar os clusters.

# %% [markdown]
# ---
# # Case Elo7 - Subcategorias Automáticas
#
# Vamos para mais um case real do Elo7!
#
# Esse case é um dos trabalhos mais recentes do time de Data Science do Elo7. De fato, é um trabalho ainda em aberto e qualquer sugestão de melhorias é bem vinda! =)
#
# - O problema:
# O Elo7 possui uma árvore de categorias dividida em N1 e N2. O primeiro nível (N1) contém as categorias "alto nível" do site. São as categorias mais genéricas do marketplace- ou, pelo menos, é assim gostaríamos que fosse. As categorias N2, ou subcategorias, são as possíveis extensões dos nós das categorias N1. Podemos perceber que a árvore é extremamente limitada e isso é um problema grave não só para os compradores, que não conseguem navegar nas nossas categorias, mas também para os vendedores, que não conseguem categorizar bem seus produtos. A solução para esse problema seria uma árvore de categorias com maior "granularidade", ou seja, que consiga expandir além dos 2 níveis e ter mais subcategorias.
#
# - O que o time de Data Science tem a ver com essa história?
#
# Bom, gerar uma nova árvore de categoria pode ser uma tarefa bastante monótona e cansativa. Provavelmente deve haver algum jeito de encontrar bons agrupamentos de produtos que pudessem servir como uma nova subcategoria. Talvez algum método de clustering que utilize como features o conteúdo dos produtos pode gerar algum resultado interessante.
#
# - O experimento:
#
# O dataset a seguir possui um subconjunto de produtos que foram categorizados na categoria N1 "Casamento". Escolhemos esse conjunto de dados para iniciar nossos trabalhos, porque assim temos mais controle sobre nossos resultados. E, também, porque é uma das categorias mais importantes do marketplace.
#
# Para essa tarefa, vamos utilizar apenas o título e uma parte da descrição do produto (aprox. 140 caracteres) como features de entrada.
#
# Vamos analisar os dados!

# %%
df_cat = pd.read_csv(os.path.join(DATASET_FOLDER, 'subcategory_elo7_dataset.csv'), sep=';')

df_cat.head(10)
# Out:
#                                     title  \
# 0                    terco love ii niquel
# 1                     porta joias rustico
# 2                convite casamento lisboa
# 3                     daminhas 82 00 cada
# 4                            aromatizador
# 5  chinelo casamento personalizado noivos
# 6    monograma brasao casamento modelo 91
# 7               caixa lembrancinhas papel
# 8                body noiva personalizada
# 9        quadro casamento mario geek nerd
#
#                                    short_description  \
# 0  vc quiser simular clique produto informe cep e...
# 1  porta joias mdf presentear madrinhas lembranca...
# 2  compra minima 50 unidades convite casamento 15...
# 3                           tecido cristal voal fino
# 4  aromatizador ambientes varetas frasco vidro cu...
# 5  personalizamos qualquer tema foto precos difer...
# 6  monograma brasao casamento iniciais descricao ...
# 7  caixa cartonagem revestida papel detalhe fita ...
# 8  body personalizado madrinhas usarem despedida ...
# 9  ideal presente peca decoracao quadro eterniza ...
#
#                                         url
# 0  https://www.elo7.com.br/jfndgm/dp/36CBDF
# 1  https://www.elo7.com.br/jfndgm/dp/65FE78
# 2  https://www.elo7.com.br/jfndgm/dp/2557F0
# 3  https://www.elo7.com.br/jfndgm/dp/4D60B6
# 4  https://www.elo7.com.br/jfndgm/dp/5FECD3
# 5  https://www.elo7.com.br/jfndgm/dp/6B06A4
# 6  https://www.elo7.com.br/jfndgm/dp/B04210
# 7  https://www.elo7.com.br/jfndgm/dp/28DF6F
# 8  https://www.elo7.com.br/jfndgm/dp/AAE311
# 9  https://www.elo7.com.br/jfndgm/dp/8939E7

# %% [markdown]
# Vamos criar uma coluna com as features que vamos incluir no nosso modelo de aprendizagem.
# Esse vetor de features será o título + descrição do produto. Para compensar a quantidade de palavras do título em relação a descrição, vamos repetir o título duas vezes.

# %%
df_cat['title_desc'] = (df_cat['title'] + ' ')*2 + df_cat['short_description']

df_cat.head(10)
# Out:
#                                     title  \
# 0                    terco love ii niquel
# 1                     porta joias rustico
# 2                convite casamento lisboa
# 3                     daminhas 82 00 cada
# 4                            aromatizador
# 5  chinelo casamento personalizado noivos
# 6    monograma brasao casamento modelo 91
# 7               caixa lembrancinhas papel
# 8                body noiva personalizada
# 9        quadro casamento mario geek nerd
#
#                                    short_description  \
# 0  vc quiser simular clique produto informe cep e...
# 1  porta joias mdf presentear madrinhas lembranca...
# 2  compra minima 50 unidades convite casamento 15...
# 3                           tecido cristal voal fino
# 4  aromatizador ambientes varetas frasco vidro cu...
# 5  personalizamos qualquer tema foto precos difer...
# 6  monograma brasao casamento iniciais descricao ...
# 7  caixa cartonagem revestida papel detalhe fita ...
# 8  body personalizado madrinhas usarem despedida ...
# 9  ideal presente peca decoracao quadro eterniza ...
#
#                                         url  \
# 0  https://www.elo7.com.br/jfndgm/dp/36CBDF
# 1  https://www.elo7.com.br/jfndgm/dp/65FE78
# 2  https://www.elo7.com.br/jfndgm/dp/2557F0
# 3  https://www.elo7.com.br/jfndgm/dp/4D60B6
# 4  https://www.elo7.com.br/jfndgm/dp/5FECD3
# 5  https://www.elo7.com.br/jfndgm/dp/6B06A4
# 6  https://www.elo7.com.br/jfndgm/dp/B04210
# 7  https://www.elo7.com.br/jfndgm/dp/28DF6F
# 8  https://www.elo7.com.br/jfndgm/dp/AAE311
# 9  https://www.elo7.com.br/jfndgm/dp/8939E7
#
#                                           title_desc
# 0  terco love ii niquel terco love ii niquel vc q...
# 1  porta joias rustico porta joias rustico porta ...
# 2  convite casamento lisboa convite casamento lis...
# 3  daminhas 82 00 cada daminhas 82 00 cada tecido...
# 4  aromatizador aromatizador aromatizador ambient...
# 5  chinelo casamento personalizado noivos chinelo...
# 6  monograma brasao casamento modelo 91 monograma...
# 7  caixa lembrancinhas papel caixa lembrancinhas ...
# 8  body noiva personalizada body noiva personaliz...
# 9  quadro casamento mario geek nerd quadro casame...

# %% [markdown]
# Para criar nossa matriz de features, nós vamos utilizar o Tf-Idf.

# %%
tfidf = TfidfVectorizer(max_df=0.9, max_features=10000, sublinear_tf=True, use_idf=True)

# %%
X = tfidf.fit_transform(df_cat['title_desc'].values)

# %% [markdown]
# Novamente, precisamos definir o número de clusters. Podemos utilizar o método do gráfico de inércias.
#
# (Obs: O cálculo pode levar muito tempo para ser executado. Assuma que o valor escolhido é 40)

# %%
# Range de valores de clusters que vamos testar
k = range(10,100,10)

# Lista de inércias
inertias = []

# Para cada valor de k, ache a inércia
for i in k:
    # crie a instância
    kmeans = KMeans(n_clusters=i)

    # Treine o modelo
    model = kmeans.fit(X)

    # Ache a inercia dos clusters
    inertias.append(model.inertia_)
    
plt.plot(k, inertias, '-ob')
plt.xlabel('Clusters')
plt.ylabel('Inertia')
plt.grid()
plt.show()

# %%
kmeans = KMeans(n_clusters=40)

# %%
labels = kmeans.fit_predict(X)

# %%
df = pd.DataFrame({'title': df_cat['title'], 'labels': labels})

# %%
df.groupby('labels').size()
# Out:
# labels
# 0      1235
# 1      3653
# 2      3846
# 3      2619
# 4      2196
# 5      3902
# 6     27585
# 7      1068
# 8       967
# 9      1739
# 10     1864
# 11      774
# 12     1002
# 13     2786
# 14     1925
# 15     1025
# 16      949
# 17     2315
# 18     1080
# 19     1259
# 20     2509
# 21     1303
# 22     1023
# 23      607
# 24     2890
# 25     2885
# 26     1927
# 27      705
# 28      519
# 29      437
# 30     1938
# 31      725
# 32      313
# 33     4397
# 34     3775
# 35      932
# 36     1488
# 37     1312
# 38     5450
# 39     1076
# dtype: int64

# %%
for idx in range(len(df['labels'].unique())):
    idx_labels = df[df['labels']==idx]['title'].unique()
    print('- Cluster {}:'.format(idx + 1))
    for i in np.random.choice(idx_labels, min(len(idx_labels), 10), replace=False):
        print(' '*5, i)
    print()
# Out:
# - Cluster 1:
#       kit 80 assinaturas rosa
#       quadro flamingos
#       quadro assinaturas coracoes fundo roxo coracoes lilas
#       quadro historia casal
#       chalkboard c moldura 35x30cm tecido
#       quadro chalkboard casamento 46x66
#       quadro assinatura casamento
#       quadro stringart
#       quadro assinaturas arvore kombi balao qa1 kb
#       quadro frases livrai mal amem area laser
#
# - Cluster 2:
#       caixa caneca
#       caixa noivos personalizada
#       caixa duas divisoes
#       caixa forrada nome
#       caixa casamento cancun
#       caixa espumante baby taca
#       caixa perolas
#       caixa lembranca team bride taca
#       caixa infantil lembranca
#       caixa estrela aramada branca 10 pcs
#
# - Cluster 3:
#       taca brinde noivinhos personalizada
#       noivinhos banheira porta recado
#       noivinhos game over marcia carlos
#       noivos cachorrinho modelo humanizado
#       noivinhos caneca barril
#       potinho noivinhos
#       noivinhos caixa acrilico
#       shot casal noivinhos
#       noivinho musculacao humanizado
#       noivinhos mickey minnie
#
# - Cluster 4:
#       chaveiro ima pinguim
#       lembrancinha gravata listras chaveiro
#       mochila personalizada casamento
#       lembrancinha sais banho
#       lembrancinha casamento caneta
#       casal passarinhos lembrancinha
#       lembrancinha casamento bodas tulipas
#       lembrancinhas casamento bodas
#       lembrancinha sabonete coracao buque
#       chaveiro pimenta
#
# - Cluster 5:
#       canecas padrinhos casamento
#       taca casamento tacas madrinhas padrinhos
#       caneca personalizada padrinhos boli
#       lembranca casamento padrinhos champanhe
#       arte convite padrinhos madrinhas
#       caixa convite padrinhos n 284 completo
#       convite madrinhas padrinhos
#       casamento quebra cabeca floral padrinhos 45
#       garrafinha p pinga nomes padrinhos
#       xicaras padrinhos
#
# - Cluster 6:
#       convite rustico chic k010
#       convite casamento pedra af 1125
#       convite 15 anos debutante pink metalizad
#       convite capri relevo seco
#       convite casamento paula
#       convite casamento clarim
#       convite casamento perolado marrom
#       convite casamento laranja vermelho
#       convite thay branco perolado
#       envelope tag fio juta
#
# - Cluster 7:
#       naked cake
#       palavra love dourado mdf
#       talco personalizado
#       necessaire floral branca rosa
#       mochilinha daminha pajem impacto arts
#       chaveiro 3 1 5691
#       senhora aparecida
#       modelo pyaar
#       caixinha papel microndulado decorado
#       elipse pequeno principe
#
# - Cluster 8:
#       bem cadados
#       caixa bem casado tag
#       bem casados cenograficos
#       tag bem casado c 30un rita
#       caixa bem casado doces pao mel
#       envelope renda bem casados
#       flor bem casado fbc 07
#       caixa pao mel
#       caixa bem casado pao mel p marrom escuro claro
#       tecido bem casado c 50 unidades
#
# - Cluster 9:
#       chaveiro sapatinho cristal p embalado
#       caixinha latinha texto 11
#       caixa noivinhos acrilico fundo branc
#       chaveiro gravata acrilico 50 unids
#       topo bolo bodas ouro prata acrilico duas cores passaros
#       casal s2
#       4 tacas gin acrilico personalizada despedida solteira
#       tacas personalizadas
#       ag3 001
#       chaveiro foto lembranca
#
# - Cluster 10:
#       porta aliancas almofada renda
#       porta aliancas ceramica formato coracao
#       porta aliancas rustico dama pajen
#       porta aliancas bastidor laise
#       coracao porta aliancas flores
#       almofada porta aliancas azul royal
#       boneca porta aliancas branca
#       pajem porta aliancas
#       porta aliancas pet
#       par aliancas modelo bo 08
#
# - Cluster 11:
#       chinelo casamento new game
#       chinelo casamento frases personalizadas
#       sandalias casamento arabescos prata
#       chinelo personalizado casamento 0013
#       sandalias casamento carro noivo
#       chinelo casamento roca festa julina
#       chinelo personalizado casamento cod 0129
#       chinelo personalizado casamento cod 0185
#       chinelo casamento familia personalizado
#       sandalias casamento lesbicas
#
# - Cluster 12:
#       save the date digital camila
#       marcador livros save the date
#       save the date digital arabescos mr
#       arte digital save the date chalckboard
#       save the date madeira laranjeiras 3
#       save the date convite digital foto 5
#       save the date casamento arquivo digital
#       convite casamento digital mod 23
#       convite casamento noivinhos arte digital
#       save the date digital madeira
#
# - Cluster 13:
#       convite maleta vez pajem daminha
#       boneca daminha 30 cm
#       boneca tipo barbie v
#       boneca daminha provencal 02
#       boneca pano rafaella
#       daminhas feltro
#       boneca nina festa mod 1
#       maletinha daminha pajem 7
#       convite daminha rafaella
#       almofada pinte lave daminha 30x30cm
#
# - Cluster 14:
#       buque flores fuxico
#       caminhando v
#       buque noiva rosa sombreado 10 mini p madrinhas
#       buque noiva rosa sombreado replica 10 p madrinhas
#       buque daminha ref bdh13005
#       buque rosas broches ref 4 oferta
#       buque flores origami
#       coracao tag buque
#       buque lavandas delicadissimo
#       buque noiva cetim 24 rosas luxo
#
# - Cluster 15:
#       porta alianca pronta entrega
#       porta controle remoto 4 divisorias
#       230 porta guardanapos perola prontos
#       porta joias caixa madeira
#       porta amendoas
#       porta copos gatinhos
#       porta retrato chefe delicado
#       tag porta nao perturbe
#       aparador freio porta bolsa preta
#       porta guardanapos tecido
#
# - Cluster 16:
#       robe noiva brasao
#       robe roupao noiva mae madrinha
#       robe cetim gravata
#       robe cetim branco brasao jacar
#       robe cetim noiva brasao
#       robe piquet
#       robe longo cetim robi noiva azul royal
#       robe cetim madrinhas
#       kit 21 roupoes personalizados
#       robe cetim madrinha pink
#
# - Cluster 17:
#       cabide noiva acrilico preto luxo
#       cabide mdf inicias noivos
#       cabide nomes noivos coracao vazado
#       cabide princesas
#       cabide romantico p noiva off white 595
#       cabides noivo noiva
#       cabide meio meio
#       cabide nomes pombinhos arame
#       cabide noiva mdf cru 9mm m2
#       cabide mdf casamento
#
# - Cluster 18:
#       convite padrinhos
#       placas cadeira casamento
#       prmocao convite casamento
#       tags personalizadas
#       convite padrinhos madrinhas
#       convites especiais
#       convites casamento
#       placa cadeira
#       convite casamento personalizado
#       convite bodas
#
# - Cluster 19:
#       20 tag rustica lagrimas alegria 5cm
#       lenco lagrimas alegria iiii
#       lagrimas alegria rosa chiclete
#       kit 100 lagrimas alegria
#       tag lagrimas alegria
#       100 lagrimas alegria floral jb
#       100 lagrimas alegria floral k g
#       caixinha lagrimas alegria
#       tag lagrimas alegria pombinhos
#       lagrimas alegria v
#
# - Cluster 20:
#       convite casamento julia vinicius
#       passarinhos casamento filhotinho
#       iniciais coracao mdf passaros
#       convite floral marsala vinho
#       cardapio rosa marrom
#       convite personalizado casamento
#       caixa mdf brasao floral 20x20x5
#       latinha casamento
#       cachepo 20 lapis
#       chinelo havaianas casamento all you need is love
#
# - Cluster 21:
#       chalkboard 40 x 30 cm placa pronta
#       placa reservado mesa fernanda
#       placa carro noivos coracao rosa
#       placa moldura polaroid
#       placa cerimonial
#       placa mdf ondulada enfim noivos
#       placa oval vazada laser la vem noiva
#       placa deus abencoou amor 35 x 25cm
#       kit identificacao resrvado noivos
#       placa arabesco 29x19
#
# - Cluster 22:
#       terco noiva perolas cristais marsala
#       terco noiva cristal ab bendita aparecida
#       terco noiva cristal tcheco medio boreal
#       terco devocao personalizado
#       terco religioso fe divino
#       terco noivas rosinhas senhora
#       terco noiva sagrada familia banho ouro
#       terco noiva cristal ab folheado prata
#       terco cristal relicario pronta entrega
#       terco daminha
#
# - Cluster 23:
#       necessaire toalhinha bordada
#       toalha rosto irma irmao
#       4 toalha mesa oxford festas 145x145
#       toalha personalizada lavabo dohler
#       presente casamento bodas prata jogo banho bordado
#       canga toalha personalizada noivas
#       toalhinhas bordadas
#       toalha bordada noivos casamento namorado
#       toalha banho 2 unidades
#       toalha lavabo brasao 442 guipir
#
# - Cluster 24:
#       pista danca casamento 1x1 personalizada 37
#       pista danca casamento 4x4 personalizada 37
#       pista danca 5x5 personalizada 76
#       pista danca personalizada 1 50 x 1 50 md62
#       pista danca 4x4 personalizada 10
#       tapete pista danca 2x2m tp cas 179
#       pista danca 5x5 personalizada 5a
#       pista danca casamento 2x2 m mod 004
#       tapete lona pista danca 15 anos 1 5x1 5 md68
#       tapete pista danca 2x2m tp cas 192
#
# - Cluster 25:
#       150 porta guardanapo frufru
#       porta guardanapo casal flamingo
#       porta guardanapo brasao 1069
#       porta guardanapo rs rustico
#       porta guardanapo cravina tecido
#       porta guardanapo perola trancado 7
#       guardanapo anel estrela mar
#       180 porta guardanapo luxo
#       porta guardanapo rustico juta renda
#       50 unidades porta guardanapo dourado
#
# - Cluster 26:
#       convite casamento rosa floral digital
#       chalkboard casamento arte digital mod2
#       convite digital noivado
#       arte digital convite formula amor
#       tempo casamento arte digital
#       convite digital noivado amarilis
#       chalkboard casamento arte digital mod10 entrega rapida
#       monograma brasao casamento modelo 25
#       convite casamento chalkboard digital
#       cartao namorados foto digital
#
# - Cluster 27:
#       mini dedal pombinha
#       mini mobile tsuru casal ventosa
#       vela mini bolo
#       caixinha 2 sabonete noivado
#       mini album fotos mini album convite
#       suspiro amor
#       saches
#       kit mini bouquet conchas porta alianca
#       caixa mini champanhe doces
#       mini cavalete mensagem noivos verde
#
# - Cluster 28:
#       aromatizador sabonete liquido prata
#       kit presente padrinhos
#       aromatizador 50ml vidro cubo
#       kit aromatizador luxo 60ml sacolinha
#       aromatizador caixinha personalizado 50ml
#       lembrancinha aromatizador p maternidade
#       sabonete liquiido difusor
#       aromatizador personalizado casamento
#       aromatizador 50ml
#       aromatizador ambiente cubo 350ml
#
# - Cluster 29:
#       buque porta aliancas santo antonio feltro
#       porta alianca prata santo antonio
#       kit santo antonio porta aliancas buque
#       buque santo antonio 15 cm
#       santo antonio chaveiro oracao
#       santo antonio 994
#       tercos noivas santo antonio perolas
#       santo antonio padua
#       chaveirinho santo antonio
#       buque santo antonio 05 santinhos
#
# - Cluster 30:
#       long drink mulher maravilha
#       copo long drink personalizado roxo 350ml
#       copo long drink 15 anos 330ml neon
#       copo long drink casamento bonequinhos
#       copo long drink noivado
#       copos long drink personalizado casamento
#       copo long drink brasao
#       kit casamento
#       copos long drink branco casamento
#       copo noivado metalizado
#
# - Cluster 31:
#       flor papel casamento 2 unid ariana 50cm
#       arranjo floral
#       flor lapela amarela
#       headband strass prata flor off white
#       bico pato rosas
#       flor origami cabo lilas metalico
#       vaso flores v
#       voilette noiva casquete veu
#       flor rosa cetim organza
#       flor lapela azul feltro
#
# - Cluster 32:
#       brincos zirconia br051
#       brinco solitario 6 mm
#       kit noivas brinco colar pulseira nupcial
#       brinco docura
#       brinco dourado chaton argola perolas
#       brinco sequencia strass cristal
#       brinco fetiche
#       brincos strass s003
#       turquoise swarovski
#       brinco zirconias fabuloso
#
# - Cluster 33:
#       cesta florista coracoes
#       cesta florista perola vermelha
#       cesta aramada laco
#       porta aliancas cesta liga
#       cesta banho
#       cesta aliancas perola champanhe
#       cesta babado vermelho branco
#       cesta florista rosas cereja
#       cesta butterfly oval g off white
#       conjunto cesta florista porta alincas
#
# - Cluster 34:
#       noivinhos topo bolo casamento
#       casal dachshund topo bolo
#       topo bolo noivinho violoncelo 012
#       topo bolo personalizado casamento 5
#       noivo bolo
#       topo bolo noivinhos jozianne
#       noivinho
#       topo bolo bodas noivinhos
#       topo bolo casamento bruna
#       topo bolo biscuit moto
#
# - Cluster 35:
#       kit suspensorio azul tiffany gravata
#       kit love noivado
#       kit toalete festa 15 anos completo
#       kit almofada mascara 10 unidades
#       kits toilet 2 kits toilet bege
#       kit banheiro masculino personalizado
#       acessorios aniversario
#       kit maleta odorizador
#       kit ressaca sacola brinde cs004
#       kit toalha tnt decoracao festa casamento tacas
#
# - Cluster 36:
#       kit presente madrinha padrinho
#       manual padrinho madrinha pais noivos daminha
#       caneca madrinha rustico romantico
#       colar madrinha swarovski
#       champagne madrinha 750ml rotulo
#       bata feminina madrinha princesa
#       pedido personalizado joana alvarenga
#       caneca plastica madrinha casamento
#       kit madrinha maiara
#       caixinha lembancinha madrinha 3 90 cada
#
# - Cluster 37:
#       tag docinho cha lingerie
#       convite digital cha bar whatsapp
#       lembrancinha cha bar colher pau
#       tubete cha lingerie
#       taca acrilico cha lingerie
#       convite eventos
#       plaquinha divertida cha panela
#       caderno cha panela personalizado
#       mini caixa cha
#       convite digital cha panela tiffany
#
# - Cluster 38:
#       caneca personalizada casamento 1
#       caneca ceramica preta monograma
#       caneca soldadinho chumbo
#       caneca casamento beijo
#       caneca acrilica 500ml graca
#       caneca personalizada ceramica
#       caneca crianca
#       caneca super padrinho
#       caneca personalizada madrinha
#       caneca chopp festa boteco
#
# - Cluster 39:
#       convite casamento tulipa
#       casamento convite tradicional
#       cartao convite foto
#       convite renata carlos
#       convite casamento aspen rosas amarelas
#       convite casamento express 04
#       convite tiana naveen
#       convite download casamento chocolate
#       convite casamento wellintton sara
#       convite floral amarelo
#
# - Cluster 40:
#       fio tranca perolas cristais
#       tiara cravejada
#       fio perolas cristais 60cm
#       grinalda cristais
#       tiara noiva arranjo flores
#       tiara flores daminha
#       tiara strass flor noiva
#       tiara tatiana
#       tiara daminha florista casamento
#       porta coque strass swarovski

# %%
from scipy.cluster.hierarchy import linkage, dendrogram, fcluster

Y = linkage(kmeans.cluster_centers_, method='ward', metric='euclidean')

# %%
titles = df.groupby('labels').apply(lambda x: np.random.choice(list(x['title'])))

# %%
plt.figure(figsize=(16,10))
dendrogram(Y,
           labels=titles.values,
           leaf_rotation=90,
           leaf_font_size=14,
)
plt.show()
