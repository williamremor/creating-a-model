# %%
import numpy as np
import pandas as pd
from sklearn import linear_model
import matplotlib.pyplot as plt
from sklearn.neighbors import  KNeighborsClassifier
from sklearn import metrics
from sklearn.metrics import classification_report
from sklearn.metrics import confusion_matrix

# %% [markdown]
# # diagnosing classification predictions

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# # metrics from the confusion matrix

# %% [markdown]
# * precision ![image.png](attachment:image.png)

# %% [markdown]
# * recall ![image.png](attachment:image.png)

# %% [markdown]
# * F1 score ![image.png](attachment:image.png)

# %%
* high precision: not many real emails predicted as spam (BAD)
* high recall: predicted most spam emails correctly (GOOD)

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
#instantiate a k-NN classifier
knn =  KNeighborsClassifier(n_neighbors=4)
#create training and test set
X_train,  X_test, y_train,  y_test =  train_test_split(X, y, test_size=0.4,  random_state=42)
#fit the classifier to the training data
knn.fit(X_train,  y_train)
#predict the labels of the test data
y_pred =  knn.predict(X_test)

# %%
print(confusion_matrix(y_test, y_pred))
# Out:
# [[0 0 1 0]
#  [0 0 2 0]
#  [0 0 0 0]
#  [0 0 1 0]]

# %%
print(classification_report(y_test, y_pred))
# Out:
#              precision    recall  f1-score   support
#
#           1       0.00      0.00      0.00         1
#           2       0.00      0.00      0.00         2
#           3       0.00      0.00      0.00         0
#           4       0.00      0.00      0.00         1
#
# avg / total       0.00      0.00      0.00         4
# C:\Users\tati\Anaconda3\lib\site-packages\sklearn\metrics\classification.py:1135: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples.
#   'precision', 'predicted', average, warn_for)
# C:\Users\tati\Anaconda3\lib\site-packages\sklearn\metrics\classification.py:1137: UndefinedMetricWarning: Recall and F-score are ill-defined and being set to 0.0 in labels with no true samples.
#   'recall', 'true', average, warn_for)
